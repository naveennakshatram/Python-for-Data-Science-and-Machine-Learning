# %% [markdown]
# # SF Salaries Exercise
#
# ##  Dataset source is 'Kaggle'
#
# ###  URL : https://www.kaggle.com/datasets/kaggle/sf-salaries

# %%
import pandas as pd

# %%
# Read Salaries from ".csv" file 


salaries = pd.read_csv("./DataSets/Salaries.csv")

salaries
# Out:
# /var/folders/pg/b2pnn0z17pb8wmv8fch7fkph0000gn/T/ipykernel_80960/1132028726.py:4: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   salaries = pd.read_csv("./DataSets/Salaries.csv")
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# ...

# %%
salaries.head()  # The head() function will return 1st 5 rows.
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
salaries.head(2) # we can pass number of rows as a parameter in head function
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# 1  2011    NaN  San Francisco    NaN

# %%
salaries.head(10) # we can pass number of rows as a parameter in head function
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# ...

# %%
salaries.info()  # Info function will return the information of DataFrame
                 # Like
                 # Total no of Rows and cols
                 # Column Names with data type 
                 # etc.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
# To find the average BasePay.

salaries['BasePay'].mean()

# This will return error because som rows are having data which is not int/float type .
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 salaries['BasePay'].mean()
#       3 # This will return error because som rows are having data which is not int/float type .
#
# File ~/Desktop/My Documents/CNCF/Python-for-Data-Science-and-Machine-Learning/myvenv/lib/python3.12/site-packages/pandas/core/series.py:6560, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6552 @doc(make_doc("mean", ndim=1))
#    6553 def mean(
#    6554     self,
#    (...)   6558     **kwargs,
#    6559 ):
# -> 6560     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/Desktop/My Documents/CNCF/Python-for-Data-Science-and-Machine-Learning/myvenv/lib/python3.12/site-packages/pandas/core/generic.py:12439, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12432 def mean(
#   12433     self,
# ...

# %%
# Solution to find average of BasePay is.

# First we need to convert evenry thing into numeric type.

basepay = pd.to_numeric(salaries['BasePay'], errors='coerce')

print(basepay)

print("Average BasePay = ",basepay.mean())
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148649         0.00
# 148650          NaN
# 148651          NaN
# 148652          NaN
# 148653         0.00
# Name: BasePay, Length: 148654, dtype: float64
# Average BasePay =  66325.44884048769

# %%
print("Highest BasePay = ",basepay.max())
# Out:
# Highest BasePay =  319275.01

# %%
# Find the Highest pay for Overtime

print(salaries['OvertimePay'])

# Convert all colums into numaric type

overtime_pay = pd.to_numeric(salaries['OvertimePay'],errors='coerce')

print("Highest Pay of Overtime is ",overtime_pay.max())
# Out:
# 0                  0.0
# 1            245131.88
# 2            106088.18
# 3             56120.71
# 4               9737.0
#               ...
# 148649            0.00
# 148650    Not Provided
# 148651    Not Provided
# 148652    Not Provided
# 148653            0.00
# Name: OvertimePay, Length: 148654, dtype: object
# Highest Pay of Overtime is  245131.88

# %%
# Find the Job Title with Employee Name 
# Employee Name is : 'JOSEPH DRISCOLL'

salaries[salaries['EmployeeName'] == 'JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
# Print the TotalPayBenfits of given employee
# Employee Name : 'JOSEPH DRISCOLL'

salaries[salaries['EmployeeName'] == 'JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
# Find the Employee Name who is paid highest Total Pay Benfits

salaries[salaries['TotalPayBenefits'] == salaries['TotalPayBenefits'].max()]['EmployeeName']
# Out:
# 0    NATHANIEL FORD
# Name: EmployeeName, dtype: object

# %%
# Find the Employee Name who is paid Lowest Total Pay Benfits

salaries[salaries['TotalPayBenefits'] == salaries['TotalPayBenefits'].min()]['EmployeeName']
# Out:
# 148653    Joe Lopez
# Name: EmployeeName, dtype: object

# %%
# Find unique Job Titles ...!

salaries['JobTitle'].unique()
# Out:
# array(['GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY',
#        'CAPTAIN III (POLICE DEPARTMENT)',
#        'WIRE ROPE CABLE MAINTENANCE MECHANIC', ..., 'Conversion',
#        'Cashier 3', 'Not provided'], shape=(2159,), dtype=object)

# %%
# Find howmany unique job titles ..?

salaries['JobTitle'].nunique()
# Out:
# 2159

# %%
# What are the top 5 most common Jobs ?

salaries['JobTitle'].value_counts().head()
# Out:
# JobTitle
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: count, dtype: int64

# %%
# How many job titles were represented by only one person in 2013?

sum(salaries[salaries['Year'] == 2013]['JobTitle'].value_counts() == 1)
# Out:
# 202

# %%
# How many people have the word cheif in their job Title?

# using custom function we are solving this...!


def checkCHIEF(value):
    if 'CHIEF' in value or 'chief' in value:
        return True
    return False

booleans = salaries['JobTitle'].apply(lambda title : checkCHIEF(title))

len(salaries[booleans])
# Out:
# 204
